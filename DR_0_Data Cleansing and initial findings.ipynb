# %% [markdown]
# # Data Cleansing and initial findings

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\deeparam\\Desktop\\DMCA\\Sols_DSP_Capstone_Projects_PS_Chegg_2019\\6. TEXT MINING - ONLINE JOB POSTING\data job posts.csv')

# %%
df.head()
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\nJOB TITL...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\nJOB...   Jan 7, 2004
# 3  Manoff Group\nJOB TITLE:  BCC Specialist\nPOSI...   Jan 7, 2004
# 4  Yerevan Brandy Company\nJOB TITLE:  Software D...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# ...

# %%
df.columns
# Out:
# Index([u'jobpost', u'date', u'Title', u'Company', u'AnnouncementCode', u'Term',
#        u'Eligibility', u'Audience', u'StartDate', u'Duration', u'Location',
#        u'JobDescription', u'JobRequirment', u'RequiredQual', u'Salary',
#        u'ApplicationP', u'OpeningDate', u'Deadline', u'Notes', u'AboutC',
#        u'Attach', u'Year', u'Month', u'IT'],
#       dtype='object')

# %% [markdown]
# # Jobs Count by Year

# %%
df_year = df.groupby(df["Year"]).count()

# %%
df_year['jobpost'].plot(style='.-')

# %% [markdown]
# #performing non-text mining with data exploration, doing a simple plot of the job postings by the year. We see that the number of job postings has increased throughout the years, with a dip in the year 2009.The number of job postings increasing is either indicative of the economy of Armenia expanding, or there is a shift towards online job postings as opposed to traditional media job postings in general or a function of both.

# %%
#Jobs Description

# %%
df["JobDescription"].head(10)
# Out:
# 0    AMERIA Investment Consulting Company is seekin...
# 1                                                  NaN
# 2    Public outreach and strengthening of a growing...
# 3    The LEAD (Local Enhancement and Development fo...
# 4                                                  NaN
# 5       Saleswoman will sell menswear and accessories.
# 6    The Armenian Branch Office of the Open Society...
# 7                                                  NaN
# 8                                                  NaN
# 9    The incumbent assists in coordinating INL-fund...
# Name: JobDescription, dtype: object

# %%
df_company_count = df.groupby(['Company']).count()

df_company_count["jobpost"].head(50)
# Out:
# Company
# ""Aregak" Universal Credit Organization" CJSC     7
# ""Armenia" International Airport" CJSC            1
# ""Armenia" International Airports" CJCS           1
# ""Armenia" International Airports" CJSC           3
# "4h" LLC                                          4
# "A.B." LLC                                        1
# "ABM Soft Prof" Ltd.                              2
# "ACBA-Credit Agricole Bank" CJSC                  3
# "ACRA Credit Reporting CJSC                       1
# "ACRA Credit Reporting" CJSC                      6
# "ADF Shops" CJSC                                  5
# "ALGO" Educational Center                         3
# "AMI Novosti-Armenia" Information Agency LLC      2
# "ARGE Business" LLC                               1
# "ATP" Charitable Foundation                       1
# "AV TV" Limited Liability Company                 1
# "AVC Balance" LTD                                 1
# "Aalyst" Ltd                                      1
# ...

# %% [markdown]
# # IT Field Identifies Whether Job is IT

# %%
df_year = df.groupby([df["Year"], df["IT"]]).count()
df_year.head()
# Out:
#             jobpost  date  Title  Company  AnnouncementCode  Term  \
# Year IT
# 2004 False      730   730    729      730                64   140
#      True       145   145    145      145                24    36
# 2005 False      930   930    930      930               101   285
#      True       208   208    208      208                37    95
# 2006 False      891   891    886      886               106   344
#
#             Eligibility  Audience  StartDate  Duration  ...  JobRequirment  \
# Year IT                                                 ...
# 2004 False          172        32        259       202  ...            466
#      True            10         8         60        48  ...            101
# 2005 False          214        19        401       384  ...            708
#      True            27        21        129       120  ...            142
# 2006 False          179        29        414       461  ...            683
#
# ...

# %% [markdown]
# # Group by month to see which months are most popular for postings

# %%
df_month = df.groupby(df["Month"]).count()
df_month['jobpost'].plot(style='.-')

# %% [markdown]
# #job postings grouped at the month level. As can be seen in the plot, job postings peak in the months of March and June and are at a low in December and January

# %% [markdown]
# # Companies posting the most often

# %% [markdown]
# #See which are the big companies which are either (1) hiring a lot (2) have super-high turnover rates

# %%
df.groupby(df["Company"]).count().sort_values(by='jobpost', ascending=False)
# Out:
#                                                     jobpost  date  Title  \
# Company
# ArmenTel CJSC                                           353   353    353
# World Vision Armenia                                    239   239    239
# Mentor Graphics Development Services CJSC               236   236    236
# Career Center NGO                                       229   229    229
# Orange Armenia                                          203   203    203
# Ameriabank CJSC                                         196   196    196
# Converse Bank CJSC                                      161   161    161
# SAS Group LLC                                           150   150    150
# UNDP Armenia Office                                     132   132    132
# Central Bank of Armenia                                 126   126    126
# Energize Global Services CJSC                           126   126    126
# OSCE Office in Yerevan                                  125   125    125
# ...

# %% [markdown]
# #Next, a summation of the number of jobs posted, grouped by the company was done.
#
# Here is a list of the top companies posting in this dataset. It can be roughly seen that most jobs are from banking or technology in this dataset.
#
# More in-depth analysis of the different job sectors will be done in text mining.
